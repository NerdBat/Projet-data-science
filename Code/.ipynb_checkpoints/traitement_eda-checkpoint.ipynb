# %% [markdown]
# # Analyse exploratoire des données (EDA) — Churn Prediction
#
# Ce notebook a pour objectif de **comprendre le dataset** avant la modélisation :
#
# - structure des données,
# - valeurs manquantes,
# - distribution de la cible `churn`,
# - analyse des variables importantes,
# - relations simples entre les variables et le churn,
# - premières interprétations métier.

# %% [markdown]
# ## 1. Imports et configuration

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid")

TARGET = "churn"

FEATURES = [
    "gender",
    "age",
    "tenure_months",
    "contract_type",
    "monthly_logins",
    "weekly_active_days",
    "avg_session_time",
    "monthly_fee",
    "payment_failures",
    "nps_score",
]

# Le notebook peut être ouvert depuis la racine du projet ou depuis le dossier Code/
if (Path.cwd() / "SOURCE" / "dataset.csv").exists():
    DATA_PATH = Path.cwd() / "SOURCE" / "dataset.csv"
elif (Path.cwd().parent / "SOURCE" / "dataset.csv").exists():
    DATA_PATH = Path.cwd().parent / "SOURCE" / "dataset.csv"
else:
    raise FileNotFoundError("Impossible de trouver SOURCE/dataset.csv")

# %% [markdown]
# ## 2. Chargement des données

# %%
df = pd.read_csv(DATA_PATH)

print(f"Dimensions : {df.shape}")
display(df.head())
# Out:
# Dimensions : (10000, 32)
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# 1            25.140088         Billing         2.0            0
# 2            27.572928         Service         3.0            0
# 3            26.420822       Technical         5.0            1
# 4            26.674579       Technical         4.0            0
#
#    email_open_rate  marketing_click_rate  nps_score survey_response  \
# 0             0.71                  0.40         27       Satisfied
# 1             0.78                  0.33        -19         Neutral
# 2             0.35                  0.49         80         Neutral
# 3             0.83                  0.15        100         Neutral
# 4             0.65                  0.44         21     Unsatisfied
#
#    referral_count churn
# 0               1     0
# 1               2     1
# 2               1     0
# 3               0     0
# 4               1     0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## 3. Vue générale

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             10000 non-null  object
#  1   gender                  10000 non-null  object
#  2   age                     10000 non-null  int64
#  3   country                 10000 non-null  object
#  4   city                    10000 non-null  object
#  5   customer_segment        10000 non-null  object
#  6   tenure_months           10000 non-null  int64
#  7   signup_channel          10000 non-null  object
#  8   contract_type           10000 non-null  object
#  9   monthly_logins          10000 non-null  int64
#  10  weekly_active_days      10000 non-null  int64
#  11  avg_session_time        10000 non-null  float64
#  12  features_used           10000 non-null  int64
#  13  usage_growth_rate       10000 non-null  float64
#  14  last_login_days_ago     10000 non-null  int64
#  15  monthly_fee             10000 non-null  int64
#  16  total_revenue           10000 non-null  int64
#  17  payment_method          10000 non-null  object
#  18  payment_failures        10000 non-null  int64
#  19  discount_applied        10000 non-null  object
#  20  price_increase_last_3m  10000 non-null  object
#  21  support_tickets         10000 non-null  int64
#  22  avg_resolution_time     10000 non-null  float64
#  23  complaint_type          7955 non-null   object
#  24  csat_score              10000 non-null  float64
#  25  escalations             10000 non-null  int64
#  26  email_open_rate         10000 non-null  float64
#  27  marketing_click_rate    10000 non-null  float64
#  28  nps_score               10000 non-null  int64
#  29  survey_response         10000 non-null  object
#  30  referral_count          10000 non-null  int64
#  31  churn                   10000 non-null  int64
# dtypes: float64(6), int64(14), object(12)
# memory usage: 2.4+ MB

# %%
display(df.describe(include="all").T.head(15))
# Out:
#                        count unique         top  freq      mean        std  \
# customer_id            10000  10000  CUST_00001     1       NaN        NaN
# gender                 10000      2        Male  5013       NaN        NaN
# age                  10000.0    NaN         NaN   NaN   45.9061  16.420416
# country                10000      7  Bangladesh  1494       NaN        NaN
# city                   10000      7      London  1518       NaN        NaN
# customer_segment       10000      3  Individual  5984       NaN        NaN
# tenure_months        10000.0    NaN         NaN   NaN   30.1557  17.099517
# signup_channel         10000      3         Web  5036       NaN        NaN
# contract_type          10000      3     Monthly  4967       NaN        NaN
# monthly_logins       10000.0    NaN         NaN   NaN    19.672   9.838003
# weekly_active_days   10000.0    NaN         NaN   NaN    3.4794   2.302283
# avg_session_time     10000.0    NaN         NaN   NaN  15.18789   6.830774
# features_used        10000.0    NaN         NaN   NaN    4.9908   2.211607
# usage_growth_rate    10000.0    NaN         NaN   NaN  0.019423   0.149567
# last_login_days_ago  10000.0    NaN         NaN   NaN    9.5052   9.799417
#
#                       min        25%        50%        75%        max
# customer_id           NaN        NaN        NaN        NaN        NaN
# gender                NaN        NaN        NaN        NaN        NaN
# age                  18.0       32.0       46.0       60.0       74.0
# country               NaN        NaN        NaN        NaN        NaN
# city                  NaN        NaN        NaN        NaN        NaN
# customer_segment      NaN        NaN        NaN        NaN        NaN
# tenure_months         1.0       16.0       30.0       45.0       59.0
# signup_channel        NaN        NaN        NaN        NaN        NaN
# contract_type         NaN        NaN        NaN        NaN        NaN
# monthly_logins        0.0       13.0       20.0       26.0       54.0
# weekly_active_days    0.0        1.0        3.0        5.0        7.0
# avg_session_time      1.0  10.391645  15.161659  19.882034  41.996411
# features_used         1.0        3.0        5.0        6.0       15.0
# usage_growth_rate   -0.58      -0.08       0.02       0.12       0.54
# last_login_days_ago   0.0        2.0        6.0       13.0       80.0

# %% [markdown]
# ## 4. Valeurs manquantes

# %%
missing_df = (
    df.isna()
      .sum()
      .rename("missing_count")
      .to_frame()
)

missing_df["missing_pct"] = 100 * missing_df["missing_count"] / len(df)
missing_df = missing_df.sort_values("missing_count", ascending=False)

display(missing_df[missing_df["missing_count"] > 0])

plt.figure(figsize=(10, 4))
missing_plot = missing_df[missing_df["missing_count"] > 0]
if len(missing_plot) > 0:
    sns.barplot(x=missing_plot.index, y=missing_plot["missing_pct"])
    plt.xticks(rotation=45, ha="right")
    plt.ylabel("% de valeurs manquantes")
    plt.title("Variables avec valeurs manquantes")
    plt.tight_layout()
    plt.show()
else:
    print("Aucune valeur manquante détectée.")
# Out:
#                 missing_count  missing_pct
# complaint_type           2045        20.45

# %% [markdown]
# ## 5. Analyse de la variable cible

# %%
churn_rate = df[TARGET].mean()
print(f"Taux de churn global : {churn_rate:.2%}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.countplot(data=df, x=TARGET, ax=axes[0])
axes[0].set_title("Répartition de la cible churn")

pd.Series({
    "Non churn": 1 - churn_rate,
    "Churn": churn_rate,
}).plot(kind="pie", autopct="%1.1f%%", ax=axes[1])
axes[1].set_ylabel("")
axes[1].set_title("Part des churners")

plt.tight_layout()
plt.show()
# Out:
# Taux de churn global : 10.21%

# %% [markdown]
# ## 6. Focus sur les variables retenues pour le modèle final

# %%
model_df = df[FEATURES + [TARGET]].copy()
display(model_df.head())
# Out:
#    gender  age  tenure_months contract_type  monthly_logins  \
# 0    Male   68             22       Monthly              26
# 1  Female   57              9       Monthly               7
# 2    Male   24             58        Yearly              19
# 3    Male   49             19        Yearly              34
# 4    Male   65             52       Monthly              20
#
#    weekly_active_days  avg_session_time  monthly_fee  payment_failures  \
# 0                   7         11.762372           30                 1
# 1                   5         26.846390           30                 1
# 2                   5         23.380065           20                 2
# 3                   7         24.243136           30                 0
# 4                   6         18.872323           50                 0
#
#    nps_score  churn
# 0         27      0
# 1        -19      1
# 2         80      0
# 3        100      0
# 4         21      0

# %% [markdown]
# ## 7. Distributions des variables numériques

# %%
numeric_features = model_df.select_dtypes(include=["int64", "float64"]).columns.drop(TARGET).tolist()

fig, axes = plt.subplots(3, 3, figsize=(15, 10))
axes = axes.flatten()

for ax, col in zip(axes, numeric_features):
    sns.histplot(model_df[col], kde=True, ax=ax)
    ax.set_title(col)

for ax in axes[len(numeric_features):]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Variables catégorielles et churn

# %%
categorical_features = ["gender", "contract_type"]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for ax, col in zip(axes, categorical_features):
    churn_by_cat = model_df.groupby(col)[TARGET].mean().sort_values(ascending=False)
    sns.barplot(x=churn_by_cat.index, y=churn_by_cat.values, ax=ax)
    ax.set_title(f"Taux de churn par {col}")
    ax.set_ylabel("Taux de churn")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Analyse de quelques facteurs de risque métier

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# payment_failures
payment_churn = model_df.groupby("payment_failures")[TARGET].mean().reset_index()
sns.lineplot(data=payment_churn, x="payment_failures", y=TARGET, marker="o", ax=axes[0])
axes[0].set_title("Churn selon les échecs de paiement")
axes[0].set_ylabel("Taux de churn")

# nps_score
nps_churn = model_df.groupby("nps_score")[TARGET].mean().reset_index()
sns.lineplot(data=nps_churn, x="nps_score", y=TARGET, marker="o", ax=axes[1])
axes[1].set_title("Churn selon le NPS")
axes[1].set_ylabel("Taux de churn")

# tenure_months (buckets)
tenure_df = model_df.copy()
tenure_df["tenure_group"] = pd.cut(
    tenure_df["tenure_months"],
    bins=[-1, 3, 6, 12, 24, 60],
    labels=["0-3", "4-6", "7-12", "13-24", "25+"]
)
tenure_churn = tenure_df.groupby("tenure_group", observed=False)[TARGET].mean().reset_index()
sns.barplot(data=tenure_churn, x="tenure_group", y=TARGET, ax=axes[2])
axes[2].set_title("Churn selon l'ancienneté")
axes[2].set_ylabel("Taux de churn")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Comparaison des distributions selon churn

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

sns.boxplot(data=model_df, x=TARGET, y="monthly_fee", ax=axes[0, 0])
axes[0, 0].set_title("Monthly fee selon churn")

sns.boxplot(data=model_df, x=TARGET, y="avg_session_time", ax=axes[0, 1])
axes[0, 1].set_title("Temps de session selon churn")

sns.boxplot(data=model_df, x=TARGET, y="monthly_logins", ax=axes[1, 0])
axes[1, 0].set_title("Connexions mensuelles selon churn")

sns.boxplot(data=model_df, x=TARGET, y="nps_score", ax=axes[1, 1])
axes[1, 1].set_title("NPS selon churn")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Corrélations entre variables numériques

# %%
corr_df = model_df[numeric_features + [TARGET]].corr(numeric_only=True)

plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matrice de corrélation")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Tableau de synthèse métier

# %%
summary = pd.DataFrame({
    "indicateur": [
        "Taux de churn global",
        "Contrat le plus risqué",
        "NPS moyen des churners",
        "NPS moyen des non churners",
        "Échecs de paiement moyens des churners",
        "Échecs de paiement moyens des non churners",
    ],
    "valeur": [
        f"{model_df[TARGET].mean():.2%}",
        model_df.groupby("contract_type")[TARGET].mean().sort_values(ascending=False).index[0],
        round(model_df.loc[model_df[TARGET] == 1, "nps_score"].mean(), 2),
        round(model_df.loc[model_df[TARGET] == 0, "nps_score"].mean(), 2),
        round(model_df.loc[model_df[TARGET] == 1, "payment_failures"].mean(), 2),
        round(model_df.loc[model_df[TARGET] == 0, "payment_failures"].mean(), 2),
    ]
})

display(summary)
# Out:
#                                    indicateur  valeur
# 0                        Taux de churn global  10.21%
# 1                      Contrat le plus risqué  Yearly
# 2                      NPS moyen des churners   19.46
# 3                  NPS moyen des non churners   19.07
# 4      Échecs de paiement moyens des churners    0.74
# 5  Échecs de paiement moyens des non churners    0.47

# %% [markdown]
# ## 13. Premières conclusions
#
# Points à commenter dans le rapport :
#
# - la classe `churn=1` est **minoritaire**, ce qui justifie l'usage de métriques comme **PR-AUC** et **Recall** ;
# - certaines variables semblent particulièrement liées au churn, par exemple :
#   - le **type de contrat**,
#   - le **NPS**,
#   - les **échecs de paiement**,
#   - l'**activité récente** ;
# - cette analyse exploratoire permet de justifier les variables retenues dans le modèle final.
